# %%
# standard library
from collections import namedtuple
import io
import os
import numpy as np
import pandas as pd

# plot.ly modules
import dash
from dash.dependencies import Output, Event
import dash_core_components as dcc
import dash_html_components as html
import plotly.graph_objs as go

# %%
df = pd.read_csv('combined_normalized.csv')
col = ['speed','pm10','pm25','no2','co']
global rows 
rows = len(df)
def get_data(rows):
    rows += 1
    print(rows)
# Out:
#   File "<ipython-input-22-6af34dc2b375>", line 5
#     def get_data(global rows):
#                       ^
# SyntaxError: invalid syntax

# %%
get_data(rows)
# Out:
# 104

# %%
# Out:
#               new_date       lat       long  speed             datetime  \
# 0  2018-07-01T05:00:00  40.70158 -73.990330  33.55  2018-07-01T05:00:00
# 1  2018-07-02T06:00:00  40.66579 -73.757060  31.68  2018-07-02T06:00:00
# 2  2018-07-02T06:00:00  40.70895 -73.996941  32.93  2018-07-02T06:00:00
# 3  2018-07-02T06:00:00  40.76212 -74.910000  18.64  2018-07-02T06:00:00
# 4  2018-07-02T06:00:00  40.74137 -74.008930  15.53  2018-07-02T06:00:00
#
#        co    no2     o3   pm10   pm25   so2  no2_normal  o3_normal  \
# 0  412.11  66.61  26.70  79.33  20.09  0.07    0.030021  -3.846154
# 1  414.54  39.52  14.46  63.54  29.13  0.83    0.132375  -0.149629
# 2  455.08  44.86  21.06  50.80  26.16  1.27    0.074749  -0.086980
# 3  333.47   8.91  24.92  17.26  16.20  0.02    0.278626  -0.071400
# 4  455.69  44.17  21.29  50.39  26.33  1.44    0.253112  -0.070668
#
#    pm10_normal  pm25_normal  so2_normal  co_normal
# 0     0.031309     0.112740   33.333333   0.008814
# ...

# %%
app = dash.Dash()

app.layout = html.Div([
    dcc.Graph(
        id='live-graph', 
    ),
    dcc.Interval(
        id='interval-component',
        interval=1*1000  # in milliseconds
    )
])


@app.callback(Output('live-graph', 'figure'),
              events=[Event('interval-component', 'interval')])
def update_graph():
#    result = get_data('data/data.csv', nlines=200)
    df = pd.read_csv('data/data.csv')
    x = df.iloc[np.random.randint(0,len(df))]
    return {
        'data': [
            go.Scatter(
                x=result.speed,
                y=result.pm25
            )
        ]
    }

# %%
if __name__ == '__main__':
    app.run_server(host='0.0.0.0')
# Out:
#  * Running on http://0.0.0.0:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [22/Jul/2018 00:02:11] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jul/2018 00:02:12] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jul/2018 00:02:12] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jul/2018 00:02:12] "GET /favicon.ico HTTP/1.1" 200 -
# [2018-07-22 00:02:13,598] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/abdulliaqat/anaconda3/lib/python3.6/site-packages/flask/app.py", line 1982, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/abdulliaqat/anaconda3/lib/python3.6/site-packages/flask/app.py", line 1614, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/abdulliaqat/anaconda3/lib/python3.6/site-packages/flask/app.py", line 1517, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
# ...

# %%
data = pd.read_csv('data/data.csv')

# %%
data.groupby(['lat','long']).get_group((40.665790,-73.757060)).to_csv('data/group_40.665790_73.757060.csv')

# %%
from time import time

# %%
int(time())+2
# Out:
# 1532214844
